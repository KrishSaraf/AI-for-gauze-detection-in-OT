# %% [markdown]
# # 1. Install Dependencies

# %% [markdown]
# pip install torch from https://pytorch.org/ based on your specs

# %%
#install YOLOv5
# !git clone https://github.com/ultralytics/yolov5
# Out:
# fatal: destination path 'yolov5' already exists and is not an empty directory.

# %%
# !cd yolov5 & pip install -r requirements.txt
# Out:
# Requirement already satisfied: gitpython>=3.1.30 in c:\users\krish\anaconda3\lib\site-packages (from -r requirements.txt (line 5)) (3.1.32)
# Requirement already satisfied: matplotlib>=3.3 in c:\users\krish\anaconda3\lib\site-packages (from -r requirements.txt (line 6)) (3.5.1)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\krish\anaconda3\lib\site-packages (from -r requirements.txt (line 7)) (1.22.4)
# Requirement already satisfied: opencv-python>=4.1.1 in c:\users\krish\anaconda3\lib\site-packages (from -r requirements.txt (line 8)) (4.8.0.76)
# Requirement already satisfied: Pillow>=7.1.2 in c:\users\krish\anaconda3\lib\site-packages (from -r requirements.txt (line 9)) (10.1.0)
# Requirement already satisfied: psutil in c:\users\krish\anaconda3\lib\site-packages (from -r requirements.txt (line 10)) (5.8.0)
# Requirement already satisfied: PyYAML>=5.3.1 in c:\users\krish\anaconda3\lib\site-packages (from -r requirements.txt (line 11)) (6.0)
# Requirement already satisfied: requests>=2.23.0 in c:\users\krish\anaconda3\lib\site-packages (from -r requirements.txt (line 12)) (2.31.0)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\krish\anaconda3\lib\site-packages (from -r requirements.txt (line 13)) (1.7.3)
# Requirement already satisfied: thop>=0.1.1 in c:\users\krish\anaconda3\lib\site-packages (from -r requirements.txt (line 14)) (0.1.1.post2209072238)
# Requirement already satisfied: torch>=1.7.0 in c:\users\krish\anaconda3\lib\site-packages (from -r requirements.txt (line 15)) (2.1.1+cu118)
# Requirement already satisfied: torchvision>=0.8.1 in c:\users\krish\anaconda3\lib\site-packages (from -r requirements.txt (line 16)) (0.16.1+cu118)
# Requirement already satisfied: tqdm>=4.64.0 in c:\users\krish\anaconda3\lib\site-packages (from -r requirements.txt (line 17)) (4.64.0)
# Requirement already satisfied: ultralytics>=8.0.100 in c:\users\krish\anaconda3\lib\site-packages (from -r requirements.txt (line 18)) (8.0.155)
# Requirement already satisfied: pandas>=1.1.4 in c:\users\krish\anaconda3\lib\site-packages (from -r requirements.txt (line 27)) (2.1.4)
# Requirement already satisfied: seaborn>=0.11.0 in c:\users\krish\anaconda3\lib\site-packages (from -r requirements.txt (line 28)) (0.11.2)
# Requirement already satisfied: setuptools>=65.5.1 in c:\users\krish\anaconda3\lib\site-packages (from -r requirements.txt (line 42)) (68.1.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\krish\anaconda3\lib\site-packages (from gitpython>=3.1.30->-r requirements.txt (line 5)) (4.0.10)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\krish\anaconda3\lib\site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (3.0.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\krish\anaconda3\lib\site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\krish\anaconda3\lib\site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\krish\anaconda3\lib\site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\krish\anaconda3\lib\site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (4.25.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\krish\anaconda3\lib\site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (21.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\krish\anaconda3\lib\site-packages (from requests>=2.23.0->-r requirements.txt (line 12)) (1.26.13)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\krish\anaconda3\lib\site-packages (from requests>=2.23.0->-r requirements.txt (line 12)) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\krish\anaconda3\lib\site-packages (from requests>=2.23.0->-r requirements.txt (line 12)) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\krish\anaconda3\lib\site-packages (from requests>=2.23.0->-r requirements.txt (line 12)) (2022.12.7)
# Requirement already satisfied: filelock in c:\users\krish\anaconda3\lib\site-packages (from torch>=1.7.0->-r requirements.txt (line 15)) (3.9.0)
# Requirement already satisfied: jinja2 in c:\users\krish\anaconda3\lib\site-packages (from torch>=1.7.0->-r requirements.txt (line 15)) (2.11.3)
# Requirement already satisfied: typing-extensions in c:\users\krish\anaconda3\lib\site-packages (from torch>=1.7.0->-r requirements.txt (line 15)) (4.4.0)
# Requirement already satisfied: sympy in c:\users\krish\anaconda3\lib\site-packages (from torch>=1.7.0->-r requirements.txt (line 15)) (1.12)
# Requirement already satisfied: networkx in c:\users\krish\anaconda3\lib\site-packages (from torch>=1.7.0->-r requirements.txt (line 15)) (3.0)
# Requirement already satisfied: fsspec in c:\users\krish\anaconda3\lib\site-packages (from torch>=1.7.0->-r requirements.txt (line 15)) (2023.4.0)
# Requirement already satisfied: colorama in c:\users\krish\anaconda3\lib\site-packages (from tqdm>=4.64.0->-r requirements.txt (line 17)) (0.4.4)
# Requirement already satisfied: py-cpuinfo in c:\users\krish\anaconda3\lib\site-packages (from ultralytics>=8.0.100->-r requirements.txt (line 18)) (9.0.0)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\krish\anaconda3\lib\site-packages (from pandas>=1.1.4->-r requirements.txt (line 27)) (2023.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\krish\anaconda3\lib\site-packages (from pandas>=1.1.4->-r requirements.txt (line 27)) (2023.3.post1)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\krish\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython>=3.1.30->-r requirements.txt (line 5)) (5.0.0)
# Requirement already satisfied: six>=1.5 in c:\users\krish\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3->-r requirements.txt (line 6)) (1.16.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\krish\anaconda3\lib\site-packages (from jinja2->torch>=1.7.0->-r requirements.txt (line 15)) (1.1.1)
# Requirement already satisfied: mpmath>=0.19 in c:\users\krish\anaconda3\lib\site-packages (from sympy->torch>=1.7.0->-r requirements.txt (line 15)) (1.3.0)
# WARNING: Ignoring invalid distribution -illow (c:\users\krish\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\krish\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\krish\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\krish\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\krish\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\krish\anaconda3\lib\site-packages)

# %% [markdown]
# # 2. Realtime Gauze Detection w/ 2 Webcams

# %%
import torch
from matplotlib import pyplot as plt
import numpy as np
import cv2
import time

# YOLOv5
model = torch.hub.load('ultralytics/yolov5', 'custom', path='../yolov5-master/202318JUL.pt', force_reload=True)
model2 = torch.hub.load('ultralytics/yolov5', 'yolov5x6', force_reload=True)

model.conf = 0.50
#model.max_det = 20
model.classes = [0]
model2.conf = 0.25
#model2.max_det = 20
model2.classes = [0]

onscreenIn, onscreenOut, countIn, countOut, frameCountIn, frameCountOut, startTime, endTime, countPlay = 0, 0, 0, 0, 0, 0, 0, 0, 0
condition = 7
cap1 = cv2.VideoCapture(0)
#Check this
cap2 = cv2.VideoCapture(1)
#cap2=cap1

while True:
    ret, frame1 = cap1.read()
    ret, frame2 = cap2.read()

    # Make detections
    pic = np.hstack((frame1, frame2))
    results = model(np.hstack((frame1, frame2)))
    results2 = model2(np.hstack((frame1, frame2)))

    a, b, c, d = 0, 0, 0, 0
    for detection in results.xyxy[0]:

        # Gauze detection
        if detection[5].item() in model.classes:
            if detection[2].item() <= frame1.shape[1]:  ##xmax < middle line
                a += 1  # Gauze in frame 1
            elif detection[2].item() > frame1.shape[1]:

                b += 1  # Gauze in frame 2

    for detection in results2.xyxy[0]:
        # Human detection
        if detection[5].item() == 0:
            if detection[2].item() <= frame1.shape[1]:  ##xmax < middle line
                c += 1 #Frame 1 human
            elif detection[2].item() > frame1.shape[1]:
                d += 1 #Frame 2 human

    image = np.squeeze(results.render())

    # Adding black border at the bottom
    borderedFrame = cv2.copyMakeBorder(image, 0, 350, 640 - frame1.shape[1], 640 - frame2.shape[1], cv2.BORDER_CONSTANT,
                                       value=[0, 0, 0])

    if c == 0:
        tempcount1 = a
        if tempcount1 != onscreenIn:
            frameCountIn += 1
            if frameCountIn == condition:
                if tempcount1 > onscreenIn:
                    countIn += tempcount1 - onscreenIn#countIn is the total in
                onscreenIn = tempcount1
        else:
            frameCountIn = 0
        cv2.putText(borderedFrame, 'On Screen =' + str(onscreenIn), (300, 30), cv2.FONT_HERSHEY_SIMPLEX, 1,
                    (255, 255, 255), 2, cv2.LINE_AA)
        cv2.putText(borderedFrame, 'Total In =' + str(countIn), (300, 55), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255),
                    2, cv2.LINE_AA)
    else:
        cv2.putText(borderedFrame, 'On Screen =' + 'Paused', (300, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2,
                    cv2.LINE_AA)
        cv2.putText(borderedFrame, 'Total In =' + 'Paused', (300, 55), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2,
                    cv2.LINE_AA)
        cv2.putText(borderedFrame, 'Human Detected', (200, 400), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2,
                    cv2.LINE_AA)

    if d == 0:
        tempcount2 = b
        if tempcount2 != onscreenOut:
            frameCountOut += 1
            if frameCountOut == condition:
                if tempcount2 > onscreenOut:
                    countOut += tempcount2 - onscreenOut
                onscreenOut = tempcount2
        else:
            frameCountOut = 0
        cv2.putText(borderedFrame, 'On Screen =' + str(onscreenOut), (940, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2,
                    cv2.LINE_AA)
        cv2.putText(borderedFrame, 'Total Out =' + str(countOut), (940, 55), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2,
                    cv2.LINE_AA)
    else:
        cv2.putText(borderedFrame, 'On Screen =' + 'Paused', (940, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
        cv2.putText(borderedFrame, 'Total Out =' + 'Paused', (940, 55), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
        cv2.putText(borderedFrame, 'Human Detected', (840, 400), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)

    # FPS Counter
    endTime = time.time()
    fps = 1 / (endTime - startTime)
    startTime = time.time()
    cv2.putText(borderedFrame, "FPS =" + str(round(fps, 1)), (540, 520), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255),
                2, cv2.LINE_AA)

    # Gauze In-Play Counter
    countPlay = countIn - onscreenIn - countOut
    cv2.putText(borderedFrame, 'In Play =' + str(countPlay), (360, 650), cv2.FONT_HERSHEY_SIMPLEX, 4, (0, 0, 255), 4,
                cv2.LINE_AA)

    cv2.imshow('Gauze', borderedFrame)

    if cv2.waitKey(10) & 0xFF == ord('q'):
        break

cap1.release()
cap2.release()
cv2.destroyAllWindows()
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to C:\Users\krish/.cache\torch\hub\master.zip
# requirements: Ultralytics requirement ['ultralytics>=8.0.232'] not found, attempting AutoUpdate...
# Requirement already satisfied: ultralytics>=8.0.232 in c:\users\krish\anaconda3\lib\site-packages (8.1.2)
# Requirement already satisfied: requests>=2.23.0 in c:\users\krish\anaconda3\lib\site-packages (from ultralytics>=8.0.232) (2.31.0)
# Requirement already satisfied: py-cpuinfo in c:\users\krish\anaconda3\lib\site-packages (from ultralytics>=8.0.232) (9.0.0)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\krish\anaconda3\lib\site-packages (from ultralytics>=8.0.232) (6.0)
# Requirement already satisfied: opencv-python>=4.6.0 in c:\users\krish\anaconda3\lib\site-packages (from ultralytics>=8.0.232) (4.8.0.76)
# Requirement already satisfied: thop>=0.1.1 in c:\users\krish\anaconda3\lib\site-packages (from ultralytics>=8.0.232) (0.1.1.post2209072238)
# Requirement already satisfied: seaborn>=0.11.0 in c:\users\krish\anaconda3\lib\site-packages (from ultralytics>=8.0.232) (0.11.2)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\krish\anaconda3\lib\site-packages (from ultralytics>=8.0.232) (3.5.1)
# Requirement already satisfied: pillow>=7.1.2 in c:\users\krish\anaconda3\lib\site-packages (from ultralytics>=8.0.232) (10.1.0)
# Requirement already satisfied: torchvision>=0.9.0 in c:\users\krish\anaconda3\lib\site-packages (from ultralytics>=8.0.232) (0.16.1+cu118)
# Requirement already satisfied: psutil in c:\users\krish\anaconda3\lib\site-packages (from ultralytics>=8.0.232) (5.8.0)
# Requirement already satisfied: numpy>=1.22.2 in c:\users\krish\anaconda3\lib\site-packages (from ultralytics>=8.0.232) (1.22.4)
# Requirement already satisfied: torch>=1.8.0 in c:\users\krish\anaconda3\lib\site-packages (from ultralytics>=8.0.232) (2.1.1+cu118)
# Requirement already satisfied: pandas>=1.1.4 in c:\users\krish\anaconda3\lib\site-packages (from ultralytics>=8.0.232) (2.1.4)
# Requirement already satisfied: tqdm>=4.64.0 in c:\users\krish\anaconda3\lib\site-packages (from ultralytics>=8.0.232) (4.64.0)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\krish\anaconda3\lib\site-packages (from ultralytics>=8.0.232) (1.7.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\krish\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics>=8.0.232) (1.3.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\krish\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics>=8.0.232) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\krish\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics>=8.0.232) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\krish\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics>=8.0.232) (3.0.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\krish\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics>=8.0.232) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\krish\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics>=8.0.232) (4.25.0)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\krish\anaconda3\lib\site-packages (from pandas>=1.1.4->ultralytics>=8.0.232) (2023.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\krish\anaconda3\lib\site-packages (from pandas>=1.1.4->ultralytics>=8.0.232) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in c:\users\krish\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics>=8.0.232) (1.16.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\krish\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics>=8.0.232) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\krish\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics>=8.0.232) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\krish\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics>=8.0.232) (1.26.13)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\krish\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics>=8.0.232) (2.1.1)
# Requirement already satisfied: fsspec in c:\users\krish\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics>=8.0.232) (2023.4.0)
# Requirement already satisfied: jinja2 in c:\users\krish\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics>=8.0.232) (2.11.3)
# Requirement already satisfied: sympy in c:\users\krish\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics>=8.0.232) (1.12)
# Requirement already satisfied: networkx in c:\users\krish\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics>=8.0.232) (3.0)
# Requirement already satisfied: filelock in c:\users\krish\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics>=8.0.232) (3.9.0)
# Requirement already satisfied: typing-extensions in c:\users\krish\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics>=8.0.232) (4.4.0)
# Requirement already satisfied: colorama in c:\users\krish\anaconda3\lib\site-packages (from tqdm>=4.64.0->ultralytics>=8.0.232) (0.4.4)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\krish\anaconda3\lib\site-packages (from jinja2->torch>=1.8.0->ultralytics>=8.0.232) (1.1.1)
# Requirement already satisfied: mpmath>=0.19 in c:\users\krish\anaconda3\lib\site-packages (from sympy->torch>=1.8.0->ultralytics>=8.0.232) (1.3.0)
#
# requirements: AutoUpdate success  9.3s, installed 1 package: ['ultralytics>=8.0.232']
# requirements:  Restart runtime or rerun command for updates to take effect
#
# YOLOv5  2024-1-16 Python-3.9.12 torch-2.1.1+cu118 CUDA:0 (NVIDIA GeForce MX250, 2048MiB)
#
# Fusing layers...
# Model summary: 267 layers, 46108278 parameters, 0 gradients, 107.6 GFLOPs
# Adding AutoShape...
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to C:\Users\krish/.cache\torch\hub\master.zip
# requirements: Ultralytics requirement ['ultralytics>=8.0.232'] not found, attempting AutoUpdate...
# Requirement already satisfied: ultralytics>=8.0.232 in c:\users\krish\anaconda3\lib\site-packages (8.1.2)
# Requirement already satisfied: torchvision>=0.9.0 in c:\users\krish\anaconda3\lib\site-packages (from ultralytics>=8.0.232) (0.16.1+cu118)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\krish\anaconda3\lib\site-packages (from ultralytics>=8.0.232) (3.5.1)
# Requirement already satisfied: torch>=1.8.0 in c:\users\krish\anaconda3\lib\site-packages (from ultralytics>=8.0.232) (2.1.1+cu118)
# Requirement already satisfied: tqdm>=4.64.0 in c:\users\krish\anaconda3\lib\site-packages (from ultralytics>=8.0.232) (4.64.0)
# Requirement already satisfied: py-cpuinfo in c:\users\krish\anaconda3\lib\site-packages (from ultralytics>=8.0.232) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in c:\users\krish\anaconda3\lib\site-packages (from ultralytics>=8.0.232) (2.1.4)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\krish\anaconda3\lib\site-packages (from ultralytics>=8.0.232) (1.7.3)
# Requirement already satisfied: requests>=2.23.0 in c:\users\krish\anaconda3\lib\site-packages (from ultralytics>=8.0.232) (2.31.0)
# Requirement already satisfied: seaborn>=0.11.0 in c:\users\krish\anaconda3\lib\site-packages (from ultralytics>=8.0.232) (0.11.2)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\krish\anaconda3\lib\site-packages (from ultralytics>=8.0.232) (6.0)
# Requirement already satisfied: pillow>=7.1.2 in c:\users\krish\anaconda3\lib\site-packages (from ultralytics>=8.0.232) (10.1.0)
# Requirement already satisfied: thop>=0.1.1 in c:\users\krish\anaconda3\lib\site-packages (from ultralytics>=8.0.232) (0.1.1.post2209072238)
# Requirement already satisfied: opencv-python>=4.6.0 in c:\users\krish\anaconda3\lib\site-packages (from ultralytics>=8.0.232) (4.8.0.76)
# Requirement already satisfied: psutil in c:\users\krish\anaconda3\lib\site-packages (from ultralytics>=8.0.232) (5.8.0)
# Requirement already satisfied: numpy>=1.22.2 in c:\users\krish\anaconda3\lib\site-packages (from ultralytics>=8.0.232) (1.22.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\krish\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics>=8.0.232) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\krish\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics>=8.0.232) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\krish\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics>=8.0.232) (4.25.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\krish\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics>=8.0.232) (3.0.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\krish\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics>=8.0.232) (1.3.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\krish\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics>=8.0.232) (21.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\krish\anaconda3\lib\site-packages (from pandas>=1.1.4->ultralytics>=8.0.232) (2023.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\krish\anaconda3\lib\site-packages (from pandas>=1.1.4->ultralytics>=8.0.232) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in c:\users\krish\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics>=8.0.232) (1.16.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\krish\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics>=8.0.232) (1.26.13)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\krish\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics>=8.0.232) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\krish\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics>=8.0.232) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\krish\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics>=8.0.232) (2022.12.7)
# Requirement already satisfied: networkx in c:\users\krish\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics>=8.0.232) (3.0)
# Requirement already satisfied: typing-extensions in c:\users\krish\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics>=8.0.232) (4.4.0)
# Requirement already satisfied: jinja2 in c:\users\krish\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics>=8.0.232) (2.11.3)
# Requirement already satisfied: fsspec in c:\users\krish\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics>=8.0.232) (2023.4.0)
# Requirement already satisfied: filelock in c:\users\krish\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics>=8.0.232) (3.9.0)
# Requirement already satisfied: sympy in c:\users\krish\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics>=8.0.232) (1.12)
# Requirement already satisfied: colorama in c:\users\krish\anaconda3\lib\site-packages (from tqdm>=4.64.0->ultralytics>=8.0.232) (0.4.4)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\krish\anaconda3\lib\site-packages (from jinja2->torch>=1.8.0->ultralytics>=8.0.232) (1.1.1)
# Requirement already satisfied: mpmath>=0.19 in c:\users\krish\anaconda3\lib\site-packages (from sympy->torch>=1.8.0->ultralytics>=8.0.232) (1.3.0)
#
# requirements: AutoUpdate success  9.0s, installed 1 package: ['ultralytics>=8.0.232']
# requirements:  Restart runtime or rerun command for updates to take effect
#
# YOLOv5  2024-1-16 Python-3.9.12 torch-2.1.1+cu118 CUDA:0 (NVIDIA GeForce MX250, 2048MiB)
#
# Fusing layers...
# YOLOv5x6 summary: 574 layers, 140730220 parameters, 0 gradients, 209.6 GFLOPs
# Adding AutoShape...
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
